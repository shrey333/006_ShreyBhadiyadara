# %%
# import modules
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
main_data = pd.read_csv('../input/data-for-transformation/data.csv')

# %%
# printing head and scatter plot
print(main_data.head())
plt.scatter(main_data["Age"], main_data["Salary"])
plt.show()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
# 2nd plot
plt.hist(main_data["Salary"], bins = 10, color = "blue")
plt.show()

# %%
# 3rd plot
fig_size = plt.figure(figsize=(7, 5))
plt.bar(main_data["Country"], main_data["Salary"], color="navy")
plt.xlabel("Salaries")
plt.ylabel("Countries")
plt.title("Bar chart of country vs salary")
plt.show()
